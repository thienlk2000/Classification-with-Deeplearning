# %%
from torch.utils.data import Dataset
import os

# %%
root_dir = 'raw-img'
class_name = os.listdir('raw-img')
file_name = {k:os.listdir(os.path.join(root_dir, k)) for k in class_name}

# %%
total = 0
for k,v in file_name.items():
    print(k, len(v))
    total += len(v)
    
print("Total:", total, 'images')
# Out:
# cane 4863
# cavallo 2623
# elefante 1446
# farfalla 2112
# gallina 3098
# gatto 1668
# mucca 1866
# pecora 1820
# ragno 4821
# scoiattolo 1862
# Total: 26179 images

# %%
import numpy as np

def split_train_val(file_name, ratio_train, ratio_val=None):
    train_set = {}
    val_set = {}
    total = 0
    for k, v in file_name.items():
        train_sample = int(len(v)*ratio_train)
        val_sample = int(len(v)*ratio_val) if ratio_val is not None else len(v) - train_sample
        shuffle_index = np.random.permutation(len(v))
        train_index = shuffle_index[:train_sample]
        val_index = shuffle_index[train_sample:train_sample+val_sample]
        train_set[k] = [v[i] for i in train_index]
        val_set[k] = [v[i] for i in val_index]
    return train_set, val_set

# %%
train_set, val_set = split_train_val(file_name, 0.5)

# %%
total = 0
for k,v in train_set.items():
    print(k, len(v))
    total += len(v)
    
print("Total:", total, 'images')
# Out:
# cane 2431
# cavallo 1311
# elefante 723
# farfalla 1056
# gallina 1549
# gatto 834
# mucca 933
# pecora 910
# ragno 2410
# scoiattolo 931
# Total: 13088 images

# %%
total = 0
for k,v in val_set.items():
    print(k, len(v))
    total += len(v)
    
print("Total:", total, 'images')
# Out:
# cane 2432
# cavallo 1312
# elefante 723
# farfalla 1056
# gallina 1549
# gatto 834
# mucca 933
# pecora 910
# ragno 2411
# scoiattolo 931
# Total: 13091 images

# %%
from torch.utils.data import Dataset, DataLoader
from PIL import Image


class AnimalDataset(Dataset):
    def __init__(self, root, file_name, transform=None):
        self.root = root
        self.file_name = file_name
        self.transform = transform
        self.all_file = [os.path.join(self.root,k,i)for k,v in self.file_name.items()  for i in v ]
        self.class_name = [k for k in self.file_name]
        self.id_to_class = {k:v for k,v in enumerate(self.class_name)}
        self.class_to_id = {v:k for k,v in self.id_to_class.items()}
    def __len__(self):
        return len(self.all_file)
    def __getitem__(self, i):
        file = self.all_file[i]
        image = Image.open(file)
        if image.mode == 'RGBA':
            image = image.convert('RGB')
        class_name = file.split('\\')[-2]
        label = self.class_to_id[class_name]
#         print(file)
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
data = AnimalDataset(root_dir, file_name)

# %%
image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-28935580a9bb> in <module>
# ----> 1 image
#
# NameError: name 'image' is not defined

# %%
data[0][0].shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-bbe381545263> in <module>
# ----> 1 data[0][0].shape
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in __getattr__(self, name)
#     539             )
#     540             return self._category
# --> 541         raise AttributeError(name)
#     542
#     543     @property
#
# AttributeError: shape

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def plot_images(imgs, num_col, num_row, normalize=False):
    mean = torch.tensor([0.4914, 0.4822, 0.4465]).view(3,1,1)
    std = torch.tensor([0.2023, 0.1994, 0.2010]).view(3,1,1)
    if normalize:
        imgs = imgs*std + mean
    num_img = imgs.shape[0]
    plt.figure()
    for i in range(1,num_img+1):
        
        plt.subplot(num_row, num_col, i)
        plt.imshow(imgs[i-1].permute(1,2,0))
        plt.axis('off')

# %%
import torchvision.transforms as T
transform = T.Compose([
    T.Resize((224,224)),
    T.ToTensor(),
    T.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
dataset = AnimalDataset(root_dir, file_name,transform)

# %%
dataset[0][0].shape, dataset[0][1]
# Out:
# (torch.Size([3, 225, 300]), 0)

# %%
plot_images(dataset[6][0].unsqueeze(0), 1, 1)

# %%
dataloader = DataLoader(dataset, batch_size=64)
batch_data, batch_label = next(iter(dataloader))
plot_images(batch_data, 8,8,normalize=True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
batch_data.shape
# Out:
# torch.Size([64, 3, 224, 224])

# %%
len(dataloader.dataset)
# Out:
# 26179

# %%
import torch.nn.functional as F
def train(model, optimizer, train_loader, val_loader, epoch=1, print_every=100):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = model.to(device)
    loss_iter = 0
    acc_iter = 0
    num_iter = 0
    train_loss = []
    train_acc = []
    val_loss = []
    val_acc = []
    batch_size = train_loader.batch_size
    num_train = len(train_loader.dataset)
    for e in range(epoch):
        for i,(x, y) in enumerate(train_loader):
            model.train()
            x = x.to(device)
            y = y.to(device)
            score = model(x)
            loss = F.cross_entropy(score, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            with torch.no_grad():
                acc_iter += (score.argmax(dim=1) == y).sum()
                num_iter += y.shape[0]
            loss_iter += loss.item()
            if i % print_every == print_every - 1 or i == len(train_loader) - 1:
                if i % print_every == print_every - 1:
                    loss_iter /= print_every
                else:
                    loss_iter /=  (num_train - (len(train_loader) - 1)*batch_size)
#             acc_train = float(acc_iter) / num_iter
                train_loss.append(loss_iter)
                train_acc.append(float(acc_iter) / num_iter)
                loss_val, acc_val = check_val_loader(model, val_loader)
                val_loss.append(loss_val)
                val_acc.append(acc_val)
                print(f"Epoch:{e}\tIteration:{i}\tTrain Loss:{loss_iter}\tTrain Accuracy:{float(acc_iter) / num_iter}")
                print(f"Epoch:{e}\tIteration:{i}\tVal Loss:{loss_val}\tVal Accuracy:{acc_val}")
                loss_iter = 0
                acc_iter = 0
                num_iter = 0
    return train_loss, train_acc, val_loss, val_acc

# %%
def check_val_loader(model, val_loader):
    with torch.no_grad():
        loss_val = 0
        acc_val = 0
        num = 0
        model.eval()
        for i, (x, y) in enumerate(val_loader):
            x = x.to(device=device)
            y = y.to(device=device)
            score = model(x)
            loss = F.cross_entropy(score, y)
            loss_val += loss.item()
            acc_val += (score.argmax(dim=1) == y).sum()
            num += y.shape[0]
        loss_val /= len(val_loader)
        acc_val = float(acc_val) / num
    return loss_val, acc_val

# %%
train_file, val_file = split_train_val(file_name, ratio_train=0.1, ratio_val=0.1)

# %%
print("All Images")

total = 0
for k,v in file_name.items():
    print(k, len(v))
    total += len(v)
    
print("Total:", total, 'images')

print("Train Set")
total = 0
for k,v in train_file.items():
    print(k, len(v))
    total += len(v)
    
print("Total:", total, 'images')

print("Val Set")
total = 0
for k,v in val_file.items():
    print(k, len(v))
    total += len(v)
    
print("Total:", total, 'images')
# Out:
# All Images
# cane 4863
# cavallo 2623
# elefante 1446
# farfalla 2112
# gallina 3098
# gatto 1668
# mucca 1866
# pecora 1820
# ragno 4821
# scoiattolo 1862
# Total: 26179 images
# Train Set
# cane 486
# cavallo 262
# elefante 144
# farfalla 211
# gallina 309
# gatto 166
# mucca 186
# pecora 182
# ragno 482
# scoiattolo 186
# Total: 2614 images
# Val Set
# cane 486
# cavallo 262
# elefante 144
# farfalla 211
# gallina 309
# gatto 166
# mucca 186
# pecora 182
# ragno 482
# scoiattolo 186
# Total: 2614 images

# %%
transform = T.Compose([
    T.Resize((224,224)),
    T.ToTensor(),
    T.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
train_set = AnimalDataset(root_dir, train_file, transform=transform)
val_set = AnimalDataset(root_dir, val_file, transform=transform)

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader = DataLoader(val_set, batch_size=64)

# %%
from alexnet import AlexNet

# %%
import torch.optim as optim
model_alex = AlexNet(num_classes=10)
optim_alex = optim.SGD(model_alex.parameters(), lr=1e-3, momentum=0.9)

# %%
train_loss, train_acc, val_loss, val_acc = train(model_alex, optim_alex, train_loader, val_loader, print_every=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-243669fe356c> in <module>
# ----> 1 train_loss, train_acc, val_loss, val_acc = train(model_alex, optim_alex, train_loader, val_loader, print_every=10)
#
# <ipython-input-74-2ecbdbc2b5da> in train(model, optimizer, train_loader, val_loader, epoch, print_every)
#      34                 train_loss.append(loss_iter)
#      35                 train_acc.append(float(acc_iter) / num_iter)
# ---> 36                 loss_val, acc_val = check_val_loader(model, val_loader)
#      37                 val_loss.append(loss_val)
#      38                 val_acc.append(acc_val)
#
# <ipython-input-73-60cc9354adeb> in check_val_loader(model, val_loader)
#       5         num = 0
#       6         model.eval()
# ----> 7         for i, (x, y) in enumerate(val_loader):
#       8             x = x.to(device=device)
# ...

# %%
batch_data, batch_label = next(iter(train_loader))

# %%
batch_data.shape, batch_label.shape
# Out:
# (torch.Size([64, 3, 224, 224]), torch.Size([64]))

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
img = Image.open("raw-img\elefante\e835b50620f0073ed1584d05fb1d4e9fe777ead218ac104497f5c978a4efbcb0_640.png")
img.mode
# Out:
# 'RGBA'

# %%
img.mode
# Out:
# <function Tensor.mode>
